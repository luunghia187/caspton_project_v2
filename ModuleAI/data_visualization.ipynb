# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the preprocessed data
data = pd.read_csv('data/processed_data.csv')

# %%
# Explore data distribution and relationships
# Example 1: Age distribution
plt.figure(figsize=(10, 6))
sns.histplot(data['age'], bins=20, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17492/2505554953.py in <module>
#       2 # Example 1: Age distribution
#       3 plt.figure(figsize=(10, 6))
# ----> 4 sns.histplot(data['age'], bins=20, kde=True)
#       5 plt.title('Age Distribution')
#       6 plt.xlabel('Age')
#
# c:\Users\NGHIA\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1414     if p.univariate:
#    1415
# -> 1416         p.plot_univariate_histogram(
#    1417             multiple=multiple,
#    1418             element=element,
#
# c:\Users\NGHIA\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py in plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     649
#     650                 line_kws["color"] = to_rgba(sub_color, 1)
# --> 651                 line, = ax.plot(
#     652                     *line_args, **line_kws,
#     653                 )
#
# c:\Users\NGHIA\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606         for line in lines:
#    1607             self.add_line(line)
#
# c:\Users\NGHIA\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     313                 this += args[0],
#     314                 args = args[1:]
# --> 315             yield from self._plot_args(this, kwargs)
#     316
#     317     def get_next_color(self):
#
# c:\Users\NGHIA\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     488
#     489         if len(xy) == 2:
# --> 490             x = _check_1d(xy[0])
#     491             y = _check_1d(xy[1])
#     492         else:
#
# c:\Users\NGHIA\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\cbook\__init__.py in _check_1d(x)
#    1360                     message='Support for multi-dimensional indexing')
#    1361
# -> 1362                 ndim = x[:, None].ndim
#    1363                 # we have definitely hit a pandas index or series object
#    1364                 # cast to a numpy array.
#
# c:\Users\NGHIA\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    5383         # Because we ruled out integer above, we always get an arraylike here
#    5384         if result.ndim > 1:
# -> 5385             disallow_ndim_indexing(result)
#    5386
#    5387         # NB: Using _constructor._simple_new would break if MultiIndex
#
# c:\Users\NGHIA\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexers\utils.py in disallow_ndim_indexing(result)
#     339     """
#     340     if np.ndim(result) > 1:
# --> 341         raise ValueError(
#     342             "Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer "
#     343             "supported. Convert to a numpy array before indexing instead."
#
# ValueError: Multi-dimensional indexing (e.g. `obj[:, None]`) is no longer supported. Convert to a numpy array before indexing instead.

# %%
# Example 2: Incident severity by age
plt.figure(figsize=(10, 6))
sns.boxplot(x='incident_severity', y='age', data=data)
plt.title('Incident Severity by Age')
plt.xlabel('Incident Severity')
plt.ylabel('Age')
plt.show()
